# %% [markdown]
# <a href="https://colab.research.google.com/github/Alahin04/Ejercicio-N17-POO-Resuelto/blob/main/Ejercicio_17_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 17 - Samuel López
import math

class Calculos:
  @staticmethod
  def cal_longitud_circunferencia(radio):
    return 2 * math.pi * radio

  @staticmethod
  def cal_area_circulo(radio):
    return math.pi * math.pow(radio,2)

radio = 3.0

longitud_circunferencia = Calculos.cal_longitud_circunferencia(radio)
area_circulo = Calculos.cal_area_circulo(radio)

print("Longitud circunferencia: ", longitud_circunferencia)
print("Area circulo: ", area_circulo)
# Out:
# Longitud circunferencia:  18.84955592153876
# Area circulo:  28.274333882308138
